# %% [markdown]
# <center>
#
# # NFT Wash Trading Detection
#
# </center>

# %%
import opensea_collection
from opensea_collection import plotRoundness, makeRoundnessVals, plotClusterPercentages, plotAllBenfordChis
import importlib
import matplotlib.pyplot as plt

# %%
collectionCSVs = [
    "0n1_force.csv",
    "axie_infinity.csv",
    "azuki.csv",
    "bored_ape.csv",
    "clone_x.csv",
    "coolmonkes.csv",
    "creature_world.csv",
    "creepz_reptile.csv",
    "creepz.csv",
    "cryptoadz.csv",
    "cryptobatz.csv",
    "cryptokitties.csv",
    "cryptopunks.csv",
    "cryptoskulls.csv",
    "cyberkongz_vx.csv",
    "DeadFellaz.csv",
    "decentraland_wearables.csv",
    "doge_pound.csv",
    "doodles.csv",
    "dr_ETHvil.csv",
    "emblem_vault.csv",
    "FLUF_world_thingies.csv",
    "fomo_mofos.csv",
    "full_send.csv",
    "hape_prime.csv",
    "hashmasks.csv",
    "lil_heroes.csv",
    "lostpoets.csv",
    "meebits.csv",
    "mekaverse.csv",
    "metroverse.csv",
    "mutant_ape.csv",
    "my_curio_cards.csv",
    "phantabear.csv",
    "pudgypenguins.csv",
    "punkcomics.csv",
    "rarible.csv",
    "rtfkt.csv",
    "sorare.csv",
    "superrare.csv",
    "wolf_game.csv",
    "world of women.csv",
    "wvrps.csv",
    "x_rabbits.csv"
]

# %%
#If you change the opensea collection file it'll need to be
#reimported to reflect any changes.
importlib.reload(opensea_collection)
# Out:
# <module 'opensea_collection' from '/Users/Connor/Documents/GitHub/NFT-Wash-Analysis/opensea_collection.py'>

# %% [markdown]
# ## First Significant Figure Analysis

# %% [markdown]
# In this section, each collections is initialized as an object. For some collections (rarible, cryptokitties) the initialization time can take several minutes, as these collections file sizes are very large in proportion to the other collections. They then visualize their distributions of first significant figures using the trade data collected for each collection.
#
# Benford's Law states that the first significant digit is likely to be small.
#
# Benford's distribution follows a percentage of:
#
# <center>
#
# | 1    |  2   |  3   |   4  |   5  |  6  |  7  |  8  |  9  |
# |------| ---- | ---- | ---- | ---- | --- | --- | --- | ----|
# | 30.1% | 17.6% | 12.5% | 9.7%  | 7.9%  | 6.7% | 5.8% | 5.1% | 4.6% |
#
# </center>
#
# In each plot the black dots represent where that percentage would lie on the plot for each point respectively.
#
# ### Chi-squared testing
#
# The Chi-squared value for each collection is shown as well. This Chi-squared value is what allows us to conclude whether or not there is a observable statistical difference in the distribution of values we *expect* compared to the distribution that we observed.
#
# ### ETH vs USD
#
# The first significant digit testing was run on both the ETH amount and the USD amount. The reasoning being that ETH acts a sort of proxy to the actual dollar amount that the buyer and seller are agreeing on, this observation is visualized by also plotting the ETH first significant digit distribution. The chi-squared test then only makes sense to run on the USD distribution.

# %% [markdown]
# <center>
#
# ### 0n1 Force
#
# </center>

# %%
force_0n1 = opensea_collection.collection(collectionCSVs[0])
force_0n1.plot_usd_fsd()

# %%
print(force_0n1.BenfordChiTest())
# Out:
# 5.965984064924808

# %%
force_0n1.plot_eth_fsd()

# %% [markdown]
# <center>
#
# ### Axie Infinity
#
# </center>

# %%
axie_infinity = opensea_collection.collection(collectionCSVs[1])
axie_infinity.plot_usd_fsd()

# %%
print(axie_infinity.BenfordChiTest())
# Out:
# 99.9580517633657

# %%
axie_infinity.plot_eth_fsd()

# %% [markdown]
# <center>
#
# ### Azuki
#
# </center>

# %%
azuki = opensea_collection.collection(collectionCSVs[2])
azuki.plot_usd_fsd()

# %%
print(azuki.BenfordChiTest())
# Out:
# 99.56298097879923

# %%
azuki.plot_eth_fsd()

# %% [markdown]
# <center>
#
# ### Bored Ape
#
# </center>

# %%
bored_ape = opensea_collection.collection(collectionCSVs[3])
bored_ape.plot_usd_fsd()

# %%
print(bored_ape.BenfordChiTest())
# Out:
# 99.7057044667959

# %%
bored_ape.plot_eth_fsd()

# %% [markdown]
# <center>
#
# ### Clone X
#
# </center>

# %%
clone_x = opensea_collection.collection(collectionCSVs[4])
clone_x.plot_usd_fsd()

# %%
print(clone_x.BenfordChiTest())
# Out:
# 99.3851577533772

# %%
clone_x.plot_eth_fsd()

# %% [markdown]
# <center>
#
# ### Coolmonkes
#
# </center>

# %%
coolmonkes = opensea_collection.collection(collectionCSVs[5])
coolmonkes.plot_usd_fsd()

# %%
print(coolmonkes.BenfordChiTest())
# Out:
# 99.50652065012225

# %%
coolmonkes.plot_eth_fsd()

# %% [markdown]
# <center>
#
# ### Creature World
#
# </center>

# %%
creature_world = opensea_collection.collection(collectionCSVs[6])
creature_world.plot_usd_fsd()

# %%
print(creature_world.BenfordChiTest())
# Out:
# 99.70087500163893

# %%
creature_world.plot_eth_fsd()

# %% [markdown]
# <center>
#
# ### Creepz Reptile
#
# </center>

# %%
creep_reptile = opensea_collection.collection(collectionCSVs[7])
creep_reptile.plot_usd_fsd()

# %%
print(creep_reptile.BenfordChiTest())
# Out:
# 99.36481769635108

# %%
creep_reptile.plot_eth_fsd()

# %% [markdown]
# <center>
#
# ### Creepz
#
# </center>

# %%
creepz = opensea_collection.collection(collectionCSVs[8])
creepz.plot_usd_fsd()

# %%
print(creepz.BenfordChiTest())
# Out:
# 99.01173013746255

# %%
creepz.plot_eth_fsd()

# %% [markdown]
# <center>
#
# ### CryptoToadz
#
# </center>

# %%
cryptotoadz = opensea_collection.collection(collectionCSVs[9])
cryptotoadz.plot_usd_fsd()

# %%
print(cryptotoadz.BenfordChiTest())
# Out:
# 99.59844380043336

# %%
cryptotoadz.plot_eth_fsd()

# %% [markdown]
# <center>
#
# ### Cryptobatz
#
# </center>

# %%
cryptobatz = opensea_collection.collection(collectionCSVs[10])
cryptobatz.plot_usd_fsd()

# %%
print(cryptobatz.BenfordChiTest())
# Out:
# 99.09552604422849

# %%
cryptobatz.plot_eth_fsd()

# %% [markdown]
# <center>
#
# ### CryptoKitties
#
# </center>

# %%
cryptokitties = opensea_collection.collection(collectionCSVs[11])
cryptokitties.plot_usd_fsd()

# %%
print(cryptokitties.BenfordChiTest())
# Out:
# 99.99024862088432

# %%
cryptokitties.plot_eth_fsd()

# %% [markdown]
# <center>
#
# ### Cryptopunks
#
# </center>

# %%
cryptopunks = opensea_collection.collection(collectionCSVs[12])
cryptopunks.plot_usd_fsd()

# %%
print(cryptopunks.BenfordChiTest())
# Out:
# 99.59904756399281

# %%
cryptopunks.plot_eth_fsd()

# %% [markdown]
# <center>
#
# ### CryptoSkulls
#
# </center>

# %%
cryptoskulls = opensea_collection.collection(collectionCSVs[13])
cryptoskulls.plot_usd_fsd()

# %%
print(cryptoskulls.BenfordChiTest())
# Out:
# 99.64610860675603

# %%
cryptoskulls.plot_eth_fsd()

# %% [markdown]
# <center>
#
# ### CyberKongz VX
#
# </center>

# %%
cyberkongz_vx = opensea_collection.collection(collectionCSVs[14])
cyberkongz_vx.plot_usd_fsd()

# %%
print(cyberkongz_vx.BenfordChiTest())
# Out:
# 99.6281996422658

# %%
cyberkongz_vx.plot_eth_fsd()

# %% [markdown]
# <center>
#
# ### DeadFellaz
#
# </center>

# %%
deadfellaz = opensea_collection.collection(collectionCSVs[15])
deadfellaz.plot_usd_fsd()

# %%
print(deadfellaz.BenfordChiTest())
# Out:
# 99.63544726209919

# %%
deadfellaz.plot_eth_fsd()

# %% [markdown]
# <center>
#
# ### Decentralized Wearables
#
# </center>

# %%
decentralized_wearables = opensea_collection.collection(collectionCSVs[16])
decentralized_wearables.plot_usd_fsd()

# %%
print(decentralized_wearables.BenfordChiTest())
# Out:
# 96.97509826610288

# %%
decentralized_wearables.plot_eth_fsd()

# %% [markdown]
# <center>
#
# ### Doge Pound
#
# </center>

# %%
doge_pound = opensea_collection.collection(collectionCSVs[17])
doge_pound.plot_usd_fsd()

# %%
print(doge_pound.BenfordChiTest())
# Out:
# 99.60080374939885

# %%
doge_pound.plot_eth_fsd()

# %% [markdown]
# <center>
#
# ### Doodles
#
# </center>

# %%
doodles = opensea_collection.collection(collectionCSVs[18])
doodles.plot_usd_fsd()

# %%
print(doodles.BenfordChiTest())
# Out:
# 99.62337646360886

# %%
doodles.plot_eth_fsd()

# %% [markdown]
# <center>
#
# ### Dr. ETHvil
#
# </center>

# %%
dr_ethvil = opensea_collection.collection(collectionCSVs[19])
dr_ethvil.plot_usd_fsd()

# %%
print(dr_ethvil.BenfordChiTest())
# Out:
# 99.20118836153948

# %%
dr_ethvil.plot_eth_fsd()

# %% [markdown]
# <center>
#
# ### Emblem Vault
#
# </center>

# %%
emblem_vault = opensea_collection.collection(collectionCSVs[20])
emblem_vault.plot_usd_fsd()

# %%
print(emblem_vault.BenfordChiTest())
# Out:
# 99.59242002279132

# %%
emblem_vault.plot_eth_fsd()

# %% [markdown]
# <center>
#
# ### FLUF World Thingies
#
# </center>

# %%
fluf_world_thingies = opensea_collection.collection(collectionCSVs[21])
fluf_world_thingies.plot_usd_fsd()

# %%
print(fluf_world_thingies.BenfordChiTest())
# Out:
# 98.3065697823922

# %%
fluf_world_thingies.plot_eth_fsd()

# %% [markdown]
# <center>
#
#
# ### Fomo Mofos
#
# </center>

# %%
fomo_mofos = opensea_collection.collection(collectionCSVs[22])
fomo_mofos.plot_usd_fsd()

# %%
print(fomo_mofos.BenfordChiTest())
# Out:
# 99.36481769635108

# %%
fomo_mofos.plot_eth_fsd()

# %% [markdown]
# <center>
#
# ### Full Send
#
# </center>

# %%
full_send = opensea_collection.collection(collectionCSVs[23])
full_send.plot_usd_fsd()

# %%
print(full_send.BenfordChiTest())
# Out:
# 99.16554654679811

# %%
full_send.plot_eth_fsd()

# %% [markdown]
# <center>
#
# ### Hape Prime
#
# </center>

# %%
hape_prime = opensea_collection.collection(collectionCSVs[24])
hape_prime.plot_usd_fsd()

# %%
print(hape_prime.BenfordChiTest())
# Out:
# 98.78594610178656

# %%
hape_prime.plot_eth_fsd()

# %% [markdown]
# <center>
#
# ### Hashmasks
#
# </center>

# %%
hashmasks = opensea_collection.collection(collectionCSVs[25])
hashmasks.plot_usd_fsd()

# %%
print(hashmasks.BenfordChiTest())
# Out:
# 99.62325822294594

# %%
hashmasks.plot_eth_fsd()

# %% [markdown]
# <center>
#
# ### Lil Heroes
#
# </center>

# %%
lil_heroes = opensea_collection.collection(collectionCSVs[26])
lil_heroes.plot_usd_fsd()

# %%
print(lil_heroes.BenfordChiTest())
# Out:
# 99.05776949702208

# %%
lil_heroes.plot_eth_fsd()

# %% [markdown]
# <center>
#
# ### Lost Poets
#
# </center>

# %%
lost_poets = opensea_collection.collection(collectionCSVs[27])
lost_poets.plot_usd_fsd()

# %%
print(lost_poets.BenfordChiTest())
# Out:
# 99.69269127517668

# %%
lost_poets.plot_eth_fsd()

# %% [markdown]
# <Center>
#
# ### Meebits
#
# </center>

# %%
meebits = opensea_collection.collection(collectionCSVs[28])
meebits.plot_usd_fsd()

# %%
print(meebits.BenfordChiTest())
# Out:
# 99.53743157677621

# %%
meebits.plot_eth_fsd()

# %% [markdown]
# <center>
#
# ### MekaVerse
#
# </center>

# %%
mekaverse = opensea_collection.collection(collectionCSVs[29])
mekaverse.plot_usd_fsd()

# %%
print(mekaverse.BenfordChiTest())
# Out:
# 99.39482155443476

# %%
mekaverse.plot_eth_fsd()

# %% [markdown]
# <center>
#
# ### MetroVerse
#
# </center>

# %%
metroverse = opensea_collection.collection(collectionCSVs[30])
metroverse.plot_usd_fsd()

# %%
print(metroverse.BenfordChiTest())
# Out:
# 99.46257797353157

# %%
metroverse.plot_eth_fsd()

# %% [markdown]
# <center>
#
# ### Mutant Ape
#
# </center>

# %%
mutant_ape = opensea_collection.collection(collectionCSVs[31])
mutant_ape.plot_usd_fsd()

# %%
print(mutant_ape.BenfordChiTest())
# Out:
# 99.7159673608312

# %%
mutant_ape.plot_eth_fsd()

# %% [markdown]
# <center>
#
# ### My Curio Cards
#
# </center>

# %%
my_curio_cards = opensea_collection.collection(collectionCSVs[32])
my_curio_cards.plot_usd_fsd()

# %%
print(my_curio_cards.BenfordChiTest())
# Out:
# 99.69165157257092

# %%
my_curio_cards.plot_eth_fsd()

# %% [markdown]
# <center>
#
# ### Phantabear
#
# </center>

# %%
phantabear = opensea_collection.collection(collectionCSVs[33])
phantabear.plot_usd_fsd()

# %%
print(phantabear.BenfordChiTest())
# Out:
# 99.53223263792046

# %%
phantabear.plot_eth_fsd()

# %% [markdown]
# <center>
#
# ### PudgyPenguins
#
# </center>

# %%
pudgypenguins = opensea_collection.collection(collectionCSVs[34])
pudgypenguins.plot_usd_fsd()

# %%
print(pudgypenguins.BenfordChiTest())
# Out:
# 99.75542801169053

# %%
pudgypenguins.plot_eth_fsd()

# %% [markdown]
# <center>
#
# ### Punk Comics
#
# </center>

# %%
punk_comics = opensea_collection.collection(collectionCSVs[35])
punk_comics.plot_usd_fsd()

# %%
print(punk_comics.BenfordChiTest())
# Out:
# 99.66030076180813

# %%
punk_comics.plot_eth_fsd()

# %% [markdown]
# <center>
#
# ### Rarible
#
# </center>

# %%
rarible = opensea_collection.collection(collectionCSVs[36])
rarible.plot_usd_fsd()

# %%
print(rarible.BenfordChiTest())
# Out:
# 99.95569997147201

# %%
rarible.plot_eth_fsd()

# %% [markdown]
# <center>
#
# ### Rtfkt
#
# </center>

# %%
rtfkt = opensea_collection.collection(collectionCSVs[37])
rtfkt.plot_usd_fsd()

# %%
print(rtfkt.BenfordChiTest())
# Out:
# 98.77832479653935

# %%
rtfkt.plot_eth_fsd()

# %% [markdown]
# <center>
#
# ### SoRare
#
# </center>

# %%
sorare = opensea_collection.collection(collectionCSVs[38])
sorare.plot_usd_fsd()

# %%
print(sorare.BenfordChiTest())
# Out:
# 99.95715691159147

# %%
sorare.plot_eth_fsd()

# %% [markdown]
# <center>
#
# ### SuperRare
#
# </center>

# %%
superrare = opensea_collection.collection(collectionCSVs[39])
superrare.plot_usd_fsd()

# %%
print(superrare.BenfordChiTest())
# Out:
# 99.64749469344916

# %%
superrare.plot_eth_fsd()

# %% [markdown]
# <center>
#
# ### Wolf Game
#
# </center>

# %%
wolf_game = opensea_collection.collection(collectionCSVs[40])
wolf_game.plot_usd_fsd()

# %%
print(wolf_game.BenfordChiTest())
# Out:
# 99.3881879364014

# %%
wolf_game.plot_eth_fsd()

# %% [markdown]
# <center>
#
# ### World of Women
#
# </center>

# %%
world_of_women = opensea_collection.collection(collectionCSVs[41])
world_of_women.plot_usd_fsd()

# %%
print(world_of_women.BenfordChiTest())
# Out:
# 99.671790615909

# %%
world_of_women.plot_eth_fsd()

# %% [markdown]
# <center>
#
# ### Wvrps
#
# </center>

# %%
wvrps = opensea_collection.collection(collectionCSVs[42])
wvrps.plot_usd_fsd()

# %%
print(wvrps.BenfordChiTest())
# Out:
# 99.29772220425518

# %%
wvrps.plot_eth_fsd()

# %% [markdown]
# <center>
#
# ### X Rabbits
#
# </center>

# %%
x_rabbits = opensea_collection.collection(collectionCSVs[43])
x_rabbits.plot_usd_fsd()

# %%
print(x_rabbits.BenfordChiTest())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [9], in <cell line: 1>()
# ----> 1 print(x_rabbits.BenfordChiTest())
#
# NameError: name 'x_rabbits' is not defined

# %%
x_rabbits.plot_eth_fsd()

# %%
opensea_collection.plotAllBenfordChis()
# Out:
# /Users/Connor/Documents/GitHub/NFT-Wash-Analysis/opensea_collection.py:137: DtypeWarning: Columns (128) have mixed types. Specify dtype option on import or set low_memory=False.
#   self.panda = pd.read_csv(directory, usecols=touseCols) # Removed low_memory=false, was running out of mem for large collections
# 0n1_force: 5.965984064924808
# /Users/Connor/Documents/GitHub/NFT-Wash-Analysis/opensea_collection.py:137: DtypeWarning: Columns (105) have mixed types. Specify dtype option on import or set low_memory=False.
#   self.panda = pd.read_csv(directory, usecols=touseCols) # Removed low_memory=false, was running out of mem for large collections
# axie_infinity: 8.144188769112885
# /Users/Connor/Documents/GitHub/NFT-Wash-Analysis/opensea_collection.py:137: DtypeWarning: Columns (105) have mixed types. Specify dtype option on import or set low_memory=False.
#   self.panda = pd.read_csv(directory, usecols=touseCols) # Removed low_memory=false, was running out of mem for large collections
# azuki.csv does not follow Benford's Law (chi square=32.977753687690445
# azuki: 32.977753687690445
# /Users/Connor/Documents/GitHub/NFT-Wash-Analysis/opensea_collection.py:137: DtypeWarning: Columns (128) have mixed types. Specify dtype option on import or set low_memory=False.
#   self.panda = pd.read_csv(directory, usecols=touseCols) # Removed low_memory=false, was running out of mem for large collections
# bored_ape: 6.466687067835863
# clone_x: 14.19457396367856
# /Users/Connor/Documents/GitHub/NFT-Wash-Analysis/opensea_collection.py:137: DtypeWarning: Columns (642) have mixed types. Specify dtype option on import or set low_memory=False.
#   self.panda = pd.read_csv(directory, usecols=touseCols) # Removed low_memory=false, was running out of mem for large collections
# coolmonkes.csv does not follow Benford's Law (chi square=33.41032785885762
# coolmonkes: 33.41032785885762
# /Users/Connor/Documents/GitHub/NFT-Wash-Analysis/opensea_collection.py:137: DtypeWarning: Columns (128) have mixed types. Specify dtype option on import or set low_memory=False.
#   self.panda = pd.read_csv(directory, usecols=touseCols) # Removed low_memory=false, was running out of mem for large collections
# creature_world: 6.395349551516753
# creepz_reptile.csv does not follow Benford's Law (chi square=16.420990363537296
# creepz_reptile: 16.420990363537296
# /Users/Connor/Documents/GitHub/NFT-Wash-Analysis/opensea_collection.py:137: DtypeWarning: Columns (105) have mixed types. Specify dtype option on import or set low_memory=False.
#   self.panda = pd.read_csv(directory, usecols=touseCols) # Removed low_memory=false, was running out of mem for large collections
# creepz.csv does not follow Benford's Law (chi square=29.688439639378114
# creepz: 29.688439639378114
# /Users/Connor/Documents/GitHub/NFT-Wash-Analysis/opensea_collection.py:137: DtypeWarning: Columns (128) have mixed types. Specify dtype option on import or set low_memory=False.
#   self.panda = pd.read_csv(directory, usecols=touseCols) # Removed low_memory=false, was running out of mem for large collections
# cryptoadz: 9.585888140136523
# /Users/Connor/Documents/GitHub/NFT-Wash-Analysis/opensea_collection.py:137: DtypeWarning: Columns (105) have mixed types. Specify dtype option on import or set low_memory=False.
#   self.panda = pd.read_csv(directory, usecols=touseCols) # Removed low_memory=false, was running out of mem for large collections
# cryptobatz.csv does not follow Benford's Law (chi square=151.58575718081298
# cryptobatz: 151.58575718081298
# /Users/Connor/Documents/GitHub/NFT-Wash-Analysis/opensea_collection.py:137: DtypeWarning: Columns (105) have mixed types. Specify dtype option on import or set low_memory=False.
#   self.panda = pd.read_csv(directory, usecols=touseCols) # Removed low_memory=false, was running out of mem for large collections
# cryptokitties: 4.530938898443246
# /Users/Connor/Documents/GitHub/NFT-Wash-Analysis/opensea_collection.py:137: DtypeWarning: Columns (105) have mixed types. Specify dtype option on import or set low_memory=False.
#   self.panda = pd.read_csv(directory, usecols=touseCols) # Removed low_memory=false, was running out of mem for large collections
# cryptopunks: 3.3560699190894328
# /Users/Connor/Documents/GitHub/NFT-Wash-Analysis/opensea_collection.py:137: DtypeWarning: Columns (128) have mixed types. Specify dtype option on import or set low_memory=False.
#   self.panda = pd.read_csv(directory, usecols=touseCols) # Removed low_memory=false, was running out of mem for large collections
# cryptoskulls.csv does not follow Benford's Law (chi square=34.801110658284045
# cryptoskulls: 34.801110658284045
# /Users/Connor/Documents/GitHub/NFT-Wash-Analysis/opensea_collection.py:137: DtypeWarning: Columns (128) have mixed types. Specify dtype option on import or set low_memory=False.
#   self.panda = pd.read_csv(directory, usecols=touseCols) # Removed low_memory=false, was running out of mem for large collections
# cyberkongz_vx: 3.9946507753963694
# /Users/Connor/Documents/GitHub/NFT-Wash-Analysis/opensea_collection.py:137: DtypeWarning: Columns (130) have mixed types. Specify dtype option on import or set low_memory=False.
#   self.panda = pd.read_csv(directory, usecols=touseCols) # Removed low_memory=false, was running out of mem for large collections
# DeadFellaz: 14.995384598033738
# /Users/Connor/Documents/GitHub/NFT-Wash-Analysis/opensea_collection.py:137: DtypeWarning: Columns (105) have mixed types. Specify dtype option on import or set low_memory=False.
#   self.panda = pd.read_csv(directory, usecols=touseCols) # Removed low_memory=false, was running out of mem for large collections
# decentraland_wearables.csv does not follow Benford's Law (chi square=20.070252112794318
# decentraland_wearables: 20.070252112794318
# /Users/Connor/Documents/GitHub/NFT-Wash-Analysis/opensea_collection.py:137: DtypeWarning: Columns (128) have mixed types. Specify dtype option on import or set low_memory=False.
#   self.panda = pd.read_csv(directory, usecols=touseCols) # Removed low_memory=false, was running out of mem for large collections
# doge_pound.csv does not follow Benford's Law (chi square=16.350431693660628
# doge_pound: 16.350431693660628
# /Users/Connor/Documents/GitHub/NFT-Wash-Analysis/opensea_collection.py:137: DtypeWarning: Columns (927) have mixed types. Specify dtype option on import or set low_memory=False.
#   self.panda = pd.read_csv(directory, usecols=touseCols) # Removed low_memory=false, was running out of mem for large collections
# doodles.csv does not follow Benford's Law (chi square=43.37958523804444
# doodles: 43.37958523804444
# dr_ETHvil.csv does not follow Benford's Law (chi square=41.45650400500662
# dr_ETHvil: 41.45650400500662
# /Users/Connor/Documents/GitHub/NFT-Wash-Analysis/opensea_collection.py:137: DtypeWarning: Columns (128) have mixed types. Specify dtype option on import or set low_memory=False.
#   self.panda = pd.read_csv(directory, usecols=touseCols) # Removed low_memory=false, was running out of mem for large collections
# emblem_vault: 5.111489569631809
# FLUF_world_thingies.csv does not follow Benford's Law (chi square=20.18057173501379
# FLUF_world_thingies: 20.18057173501379
# /Users/Connor/Documents/GitHub/NFT-Wash-Analysis/opensea_collection.py:137: DtypeWarning: Columns (128) have mixed types. Specify dtype option on import or set low_memory=False.
#   self.panda = pd.read_csv(directory, usecols=touseCols) # Removed low_memory=false, was running out of mem for large collections
# fomo_mofos.csv does not follow Benford's Law (chi square=111.280429906195
# fomo_mofos: 111.280429906195
# /Users/Connor/Documents/GitHub/NFT-Wash-Analysis/opensea_collection.py:137: DtypeWarning: Columns (105) have mixed types. Specify dtype option on import or set low_memory=False.
#   self.panda = pd.read_csv(directory, usecols=touseCols) # Removed low_memory=false, was running out of mem for large collections
# full_send.csv does not follow Benford's Law (chi square=234.61221307742525
# full_send: 234.61221307742525
# hape_prime.csv does not follow Benford's Law (chi square=201.68825984827012
# hape_prime: 201.68825984827012
# /Users/Connor/Documents/GitHub/NFT-Wash-Analysis/opensea_collection.py:137: DtypeWarning: Columns (128) have mixed types. Specify dtype option on import or set low_memory=False.
#   self.panda = pd.read_csv(directory, usecols=touseCols) # Removed low_memory=false, was running out of mem for large collections
# hashmasks.csv does not follow Benford's Law (chi square=23.44066266349738
# hashmasks: 23.44066266349738
# lil_heroes.csv does not follow Benford's Law (chi square=97.45709269984087
# lil_heroes: 97.45709269984087
# /Users/Connor/Documents/GitHub/NFT-Wash-Analysis/opensea_collection.py:137: DtypeWarning: Columns (128) have mixed types. Specify dtype option on import or set low_memory=False.
#   self.panda = pd.read_csv(directory, usecols=touseCols) # Removed low_memory=false, was running out of mem for large collections
# lostpoets.csv does not follow Benford's Law (chi square=33.30334361566697
# lostpoets: 33.30334361566697
# /Users/Connor/Documents/GitHub/NFT-Wash-Analysis/opensea_collection.py:137: DtypeWarning: Columns (105) have mixed types. Specify dtype option on import or set low_memory=False.
#   self.panda = pd.read_csv(directory, usecols=touseCols) # Removed low_memory=false, was running out of mem for large collections
# meebits: 10.175792835594587
# /Users/Connor/Documents/GitHub/NFT-Wash-Analysis/opensea_collection.py:137: DtypeWarning: Columns (128) have mixed types. Specify dtype option on import or set low_memory=False.
#   self.panda = pd.read_csv(directory, usecols=touseCols) # Removed low_memory=false, was running out of mem for large collections
# mekaverse: 7.307292600623893
# /Users/Connor/Documents/GitHub/NFT-Wash-Analysis/opensea_collection.py:137: DtypeWarning: Columns (105) have mixed types. Specify dtype option on import or set low_memory=False.
#   self.panda = pd.read_csv(directory, usecols=touseCols) # Removed low_memory=false, was running out of mem for large collections
# metroverse.csv does not follow Benford's Law (chi square=45.91946789500695
# metroverse: 45.91946789500695
# /Users/Connor/Documents/GitHub/NFT-Wash-Analysis/opensea_collection.py:137: DtypeWarning: Columns (128) have mixed types. Specify dtype option on import or set low_memory=False.
#   self.panda = pd.read_csv(directory, usecols=touseCols) # Removed low_memory=false, was running out of mem for large collections
# mutant_ape.csv does not follow Benford's Law (chi square=25.367620648856313
# mutant_ape: 25.367620648856313
# /Users/Connor/Documents/GitHub/NFT-Wash-Analysis/opensea_collection.py:137: DtypeWarning: Columns (128) have mixed types. Specify dtype option on import or set low_memory=False.
#   self.panda = pd.read_csv(directory, usecols=touseCols) # Removed low_memory=false, was running out of mem for large collections
# my_curio_cards: 2.9466478181129956
# /Users/Connor/Documents/GitHub/NFT-Wash-Analysis/opensea_collection.py:137: DtypeWarning: Columns (105) have mixed types. Specify dtype option on import or set low_memory=False.
#   self.panda = pd.read_csv(directory, usecols=touseCols) # Removed low_memory=false, was running out of mem for large collections
# phantabear.csv does not follow Benford's Law (chi square=19.542265277422977
# phantabear: 19.542265277422977
# /Users/Connor/Documents/GitHub/NFT-Wash-Analysis/opensea_collection.py:137: DtypeWarning: Columns (128) have mixed types. Specify dtype option on import or set low_memory=False.
#   self.panda = pd.read_csv(directory, usecols=touseCols) # Removed low_memory=false, was running out of mem for large collections
# pudgypenguins: 11.143275409444271
# /Users/Connor/Documents/GitHub/NFT-Wash-Analysis/opensea_collection.py:137: DtypeWarning: Columns (128) have mixed types. Specify dtype option on import or set low_memory=False.
#   self.panda = pd.read_csv(directory, usecols=touseCols) # Removed low_memory=false, was running out of mem for large collections
# punkcomics: 15.098347024433856
# /Users/Connor/Documents/GitHub/NFT-Wash-Analysis/opensea_collection.py:137: DtypeWarning: Columns (105) have mixed types. Specify dtype option on import or set low_memory=False.
#   self.panda = pd.read_csv(directory, usecols=touseCols) # Removed low_memory=false, was running out of mem for large collections
# rarible.csv does not follow Benford's Law (chi square=17.258668189631848
# rarible: 17.258668189631848
# rtfkt.csv does not follow Benford's Law (chi square=89.20053216267206
# rtfkt: 89.20053216267206
# /Users/Connor/Documents/GitHub/NFT-Wash-Analysis/opensea_collection.py:137: DtypeWarning: Columns (105) have mixed types. Specify dtype option on import or set low_memory=False.
#   self.panda = pd.read_csv(directory, usecols=touseCols) # Removed low_memory=false, was running out of mem for large collections
# sorare: 1.8739905628080331
# /Users/Connor/Documents/GitHub/NFT-Wash-Analysis/opensea_collection.py:137: DtypeWarning: Columns (105) have mixed types. Specify dtype option on import or set low_memory=False.
#   self.panda = pd.read_csv(directory, usecols=touseCols) # Removed low_memory=false, was running out of mem for large collections
# superrare: 10.510400918072877
# /Users/Connor/Documents/GitHub/NFT-Wash-Analysis/opensea_collection.py:137: DtypeWarning: Columns (105) have mixed types. Specify dtype option on import or set low_memory=False.
#   self.panda = pd.read_csv(directory, usecols=touseCols) # Removed low_memory=false, was running out of mem for large collections
# wolf_game.csv does not follow Benford's Law (chi square=17.845864687329545
# wolf_game: 17.845864687329545
# /Users/Connor/Documents/GitHub/NFT-Wash-Analysis/opensea_collection.py:137: DtypeWarning: Columns (1657) have mixed types. Specify dtype option on import or set low_memory=False.
#   self.panda = pd.read_csv(directory, usecols=touseCols) # Removed low_memory=false, was running out of mem for large collections
# world of women: 4.0179963057596755
# /Users/Connor/Documents/GitHub/NFT-Wash-Analysis/opensea_collection.py:137: DtypeWarning: Columns (856) have mixed types. Specify dtype option on import or set low_memory=False.
#   self.panda = pd.read_csv(directory, usecols=touseCols) # Removed low_memory=false, was running out of mem for large collections
# wvrps.csv does not follow Benford's Law (chi square=54.469210611065144
# wvrps: 54.469210611065144
# x_rabbits.csv does not follow Benford's Law (chi square=36.666591347226834
# x_rabbits: 36.666591347226834
# +-----------+----------------------------+
# | Graph Key |         Collection         |
# +-----------+----------------------------+
# |     1     |       0n1_force.csv        |
# |     2     |     axie_infinity.csv      |
# |     3     |         azuki.csv          |
# |     4     |       bored_ape.csv        |
# |     5     |        clone_x.csv         |
# |     6     |       coolmonkes.csv       |
# |     7     |     creature_world.csv     |
# |     8     |     creepz_reptile.csv     |
# |     9     |         creepz.csv         |
# |     10    |       cryptoadz.csv        |
# |     11    |       cryptobatz.csv       |
# |     12    |     cryptokitties.csv      |
# |     13    |      cryptopunks.csv       |
# |     14    |      cryptoskulls.csv      |
# |     15    |     cyberkongz_vx.csv      |
# |     16    |       DeadFellaz.csv       |
# |     17    | decentraland_wearables.csv |
# |     18    |       doge_pound.csv       |
# |     19    |        doodles.csv         |
# |     20    |       dr_ETHvil.csv        |
# |     21    |      emblem_vault.csv      |
# |     22    |  FLUF_world_thingies.csv   |
# |     23    |       fomo_mofos.csv       |
# |     24    |       full_send.csv        |
# |     25    |       hape_prime.csv       |
# |     26    |       hashmasks.csv        |
# |     27    |       lil_heroes.csv       |
# |     28    |       lostpoets.csv        |
# |     29    |        meebits.csv         |
# |     30    |       mekaverse.csv        |
# |     31    |       metroverse.csv       |
# |     32    |       mutant_ape.csv       |
# |     33    |     my_curio_cards.csv     |
# |     34    |       phantabear.csv       |
# |     35    |     pudgypenguins.csv      |
# |     36    |       punkcomics.csv       |
# |     37    |        rarible.csv         |
# |     38    |         rtfkt.csv          |
# |     39    |         sorare.csv         |
# |     40    |       superrare.csv        |
# |     41    |       wolf_game.csv        |
# |     42    |     world of women.csv     |
# |     43    |         wvrps.csv          |
# |     44    |       x_rabbits.csv        |
# +-----------+----------------------------+

# %% [markdown]
# ## Trade Size Clustering

# %%
opensea_collection.plotClusterPercentages()
# Out:
# /Users/Connor/Documents/GitHub/NFT-Wash-Analysis/opensea_collection.py:137: DtypeWarning: Columns (128) have mixed types. Specify dtype option on import or set low_memory=False.
#   self.panda = pd.read_csv(directory, usecols=touseCols) # Removed low_memory=false, was running out of mem for large collections
# 0n1_force: 0.9620253164556962
# /Users/Connor/Documents/GitHub/NFT-Wash-Analysis/opensea_collection.py:137: DtypeWarning: Columns (105) have mixed types. Specify dtype option on import or set low_memory=False.
#   self.panda = pd.read_csv(directory, usecols=touseCols) # Removed low_memory=false, was running out of mem for large collections
# axie_infinity: 0.9107142857142857
# /Users/Connor/Documents/GitHub/NFT-Wash-Analysis/opensea_collection.py:137: DtypeWarning: Columns (105) have mixed types. Specify dtype option on import or set low_memory=False.
#   self.panda = pd.read_csv(directory, usecols=touseCols) # Removed low_memory=false, was running out of mem for large collections
# azuki: 0.898989898989899
# /Users/Connor/Documents/GitHub/NFT-Wash-Analysis/opensea_collection.py:137: DtypeWarning: Columns (128) have mixed types. Specify dtype option on import or set low_memory=False.
#   self.panda = pd.read_csv(directory, usecols=touseCols) # Removed low_memory=false, was running out of mem for large collections
# bored_ape: 0.9536082474226805
# clone_x: 0.9065420560747663
# /Users/Connor/Documents/GitHub/NFT-Wash-Analysis/opensea_collection.py:137: DtypeWarning: Columns (642) have mixed types. Specify dtype option on import or set low_memory=False.
#   self.panda = pd.read_csv(directory, usecols=touseCols) # Removed low_memory=false, was running out of mem for large collections
# coolmonkes: 0.6875
# /Users/Connor/Documents/GitHub/NFT-Wash-Analysis/opensea_collection.py:137: DtypeWarning: Columns (128) have mixed types. Specify dtype option on import or set low_memory=False.
#   self.panda = pd.read_csv(directory, usecols=touseCols) # Removed low_memory=false, was running out of mem for large collections
# creature_world: 0.9230769230769231
# creepz_reptile: 0.6
# /Users/Connor/Documents/GitHub/NFT-Wash-Analysis/opensea_collection.py:137: DtypeWarning: Columns (105) have mixed types. Specify dtype option on import or set low_memory=False.
#   self.panda = pd.read_csv(directory, usecols=touseCols) # Removed low_memory=false, was running out of mem for large collections
# creepz: 0.9285714285714286
# /Users/Connor/Documents/GitHub/NFT-Wash-Analysis/opensea_collection.py:137: DtypeWarning: Columns (128) have mixed types. Specify dtype option on import or set low_memory=False.
#   self.panda = pd.read_csv(directory, usecols=touseCols) # Removed low_memory=false, was running out of mem for large collections
# cryptoadz: 0.85
# /Users/Connor/Documents/GitHub/NFT-Wash-Analysis/opensea_collection.py:137: DtypeWarning: Columns (105) have mixed types. Specify dtype option on import or set low_memory=False.
#   self.panda = pd.read_csv(directory, usecols=touseCols) # Removed low_memory=false, was running out of mem for large collections
# cryptobatz: 0.76
# /Users/Connor/Documents/GitHub/NFT-Wash-Analysis/opensea_collection.py:137: DtypeWarning: Columns (105) have mixed types. Specify dtype option on import or set low_memory=False.
#   self.panda = pd.read_csv(directory, usecols=touseCols) # Removed low_memory=false, was running out of mem for large collections
# cryptokitties: 0.5942028985507246
# /Users/Connor/Documents/GitHub/NFT-Wash-Analysis/opensea_collection.py:137: DtypeWarning: Columns (105) have mixed types. Specify dtype option on import or set low_memory=False.
#   self.panda = pd.read_csv(directory, usecols=touseCols) # Removed low_memory=false, was running out of mem for large collections
# cryptopunks: 0.9447236180904522
# /Users/Connor/Documents/GitHub/NFT-Wash-Analysis/opensea_collection.py:137: DtypeWarning: Columns (128) have mixed types. Specify dtype option on import or set low_memory=False.
#   self.panda = pd.read_csv(directory, usecols=touseCols) # Removed low_memory=false, was running out of mem for large collections
# cryptoskulls: 0.6086956521739131
# /Users/Connor/Documents/GitHub/NFT-Wash-Analysis/opensea_collection.py:137: DtypeWarning: Columns (128) have mixed types. Specify dtype option on import or set low_memory=False.
#   self.panda = pd.read_csv(directory, usecols=touseCols) # Removed low_memory=false, was running out of mem for large collections
# cyberkongz_vx: 0.9534883720930233
# /Users/Connor/Documents/GitHub/NFT-Wash-Analysis/opensea_collection.py:137: DtypeWarning: Columns (130) have mixed types. Specify dtype option on import or set low_memory=False.
#   self.panda = pd.read_csv(directory, usecols=touseCols) # Removed low_memory=false, was running out of mem for large collections
# DeadFellaz: 0.8636363636363636
# /Users/Connor/Documents/GitHub/NFT-Wash-Analysis/opensea_collection.py:137: DtypeWarning: Columns (105) have mixed types. Specify dtype option on import or set low_memory=False.
#   self.panda = pd.read_csv(directory, usecols=touseCols) # Removed low_memory=false, was running out of mem for large collections
# decentraland_wearables: 0.9411764705882353
# /Users/Connor/Documents/GitHub/NFT-Wash-Analysis/opensea_collection.py:137: DtypeWarning: Columns (128) have mixed types. Specify dtype option on import or set low_memory=False.
#   self.panda = pd.read_csv(directory, usecols=touseCols) # Removed low_memory=false, was running out of mem for large collections
# doge_pound: 0.7857142857142857
# /Users/Connor/Documents/GitHub/NFT-Wash-Analysis/opensea_collection.py:137: DtypeWarning: Columns (927) have mixed types. Specify dtype option on import or set low_memory=False.
#   self.panda = pd.read_csv(directory, usecols=touseCols) # Removed low_memory=false, was running out of mem for large collections
# doodles: 0.896551724137931
# dr_ETHvil: 0.45454545454545453
# /Users/Connor/Documents/GitHub/NFT-Wash-Analysis/opensea_collection.py:137: DtypeWarning: Columns (128) have mixed types. Specify dtype option on import or set low_memory=False.
#   self.panda = pd.read_csv(directory, usecols=touseCols) # Removed low_memory=false, was running out of mem for large collections
# emblem_vault: 0.8494623655913979
# FLUF_world_thingies: 0.6875
# /Users/Connor/Documents/GitHub/NFT-Wash-Analysis/opensea_collection.py:137: DtypeWarning: Columns (128) have mixed types. Specify dtype option on import or set low_memory=False.
#   self.panda = pd.read_csv(directory, usecols=touseCols) # Removed low_memory=false, was running out of mem for large collections
# fomo_mofos: 0.7647058823529411
# /Users/Connor/Documents/GitHub/NFT-Wash-Analysis/opensea_collection.py:137: DtypeWarning: Columns (105) have mixed types. Specify dtype option on import or set low_memory=False.
#   self.panda = pd.read_csv(directory, usecols=touseCols) # Removed low_memory=false, was running out of mem for large collections
# full_send: 0.6363636363636364
# hape_prime: 0.8571428571428571
# /Users/Connor/Documents/GitHub/NFT-Wash-Analysis/opensea_collection.py:137: DtypeWarning: Columns (128) have mixed types. Specify dtype option on import or set low_memory=False.
#   self.panda = pd.read_csv(directory, usecols=touseCols) # Removed low_memory=false, was running out of mem for large collections
# hashmasks: 0.9444444444444444
# lil_heroes: 0.9230769230769231
# /Users/Connor/Documents/GitHub/NFT-Wash-Analysis/opensea_collection.py:137: DtypeWarning: Columns (128) have mixed types. Specify dtype option on import or set low_memory=False.
#   self.panda = pd.read_csv(directory, usecols=touseCols) # Removed low_memory=false, was running out of mem for large collections
# lostpoets: 0.7333333333333333
# /Users/Connor/Documents/GitHub/NFT-Wash-Analysis/opensea_collection.py:137: DtypeWarning: Columns (105) have mixed types. Specify dtype option on import or set low_memory=False.
#   self.panda = pd.read_csv(directory, usecols=touseCols) # Removed low_memory=false, was running out of mem for large collections
# meebits: 0.8691588785046729
# /Users/Connor/Documents/GitHub/NFT-Wash-Analysis/opensea_collection.py:137: DtypeWarning: Columns (128) have mixed types. Specify dtype option on import or set low_memory=False.
#   self.panda = pd.read_csv(directory, usecols=touseCols) # Removed low_memory=false, was running out of mem for large collections
# mekaverse: 0.9454545454545454
# /Users/Connor/Documents/GitHub/NFT-Wash-Analysis/opensea_collection.py:137: DtypeWarning: Columns (105) have mixed types. Specify dtype option on import or set low_memory=False.
#   self.panda = pd.read_csv(directory, usecols=touseCols) # Removed low_memory=false, was running out of mem for large collections
# metroverse: 0.5333333333333333
# /Users/Connor/Documents/GitHub/NFT-Wash-Analysis/opensea_collection.py:137: DtypeWarning: Columns (128) have mixed types. Specify dtype option on import or set low_memory=False.
#   self.panda = pd.read_csv(directory, usecols=touseCols) # Removed low_memory=false, was running out of mem for large collections
# mutant_ape: 0.9026548672566371
# /Users/Connor/Documents/GitHub/NFT-Wash-Analysis/opensea_collection.py:137: DtypeWarning: Columns (128) have mixed types. Specify dtype option on import or set low_memory=False.
#   self.panda = pd.read_csv(directory, usecols=touseCols) # Removed low_memory=false, was running out of mem for large collections
# my_curio_cards: 0.9027777777777778
# /Users/Connor/Documents/GitHub/NFT-Wash-Analysis/opensea_collection.py:137: DtypeWarning: Columns (105) have mixed types. Specify dtype option on import or set low_memory=False.
#   self.panda = pd.read_csv(directory, usecols=touseCols) # Removed low_memory=false, was running out of mem for large collections
# phantabear: 0.918918918918919
# /Users/Connor/Documents/GitHub/NFT-Wash-Analysis/opensea_collection.py:137: DtypeWarning: Columns (128) have mixed types. Specify dtype option on import or set low_memory=False.
#   self.panda = pd.read_csv(directory, usecols=touseCols) # Removed low_memory=false, was running out of mem for large collections
# pudgypenguins: 0.9272727272727272
# /Users/Connor/Documents/GitHub/NFT-Wash-Analysis/opensea_collection.py:137: DtypeWarning: Columns (128) have mixed types. Specify dtype option on import or set low_memory=False.
#   self.panda = pd.read_csv(directory, usecols=touseCols) # Removed low_memory=false, was running out of mem for large collections
# punkcomics: 0.6739130434782609
# /Users/Connor/Documents/GitHub/NFT-Wash-Analysis/opensea_collection.py:137: DtypeWarning: Columns (105) have mixed types. Specify dtype option on import or set low_memory=False.
#   self.panda = pd.read_csv(directory, usecols=touseCols) # Removed low_memory=false, was running out of mem for large collections
# rarible: 0.8518518518518519
# rtfkt: 0.6949152542372882
# /Users/Connor/Documents/GitHub/NFT-Wash-Analysis/opensea_collection.py:137: DtypeWarning: Columns (105) have mixed types. Specify dtype option on import or set low_memory=False.
#   self.panda = pd.read_csv(directory, usecols=touseCols) # Removed low_memory=false, was running out of mem for large collections
# sorare: 0.5102040816326531
# /Users/Connor/Documents/GitHub/NFT-Wash-Analysis/opensea_collection.py:137: DtypeWarning: Columns (105) have mixed types. Specify dtype option on import or set low_memory=False.
#   self.panda = pd.read_csv(directory, usecols=touseCols) # Removed low_memory=false, was running out of mem for large collections
# superrare: 0.8240740740740741
# /Users/Connor/Documents/GitHub/NFT-Wash-Analysis/opensea_collection.py:137: DtypeWarning: Columns (105) have mixed types. Specify dtype option on import or set low_memory=False.
#   self.panda = pd.read_csv(directory, usecols=touseCols) # Removed low_memory=false, was running out of mem for large collections
# wolf_game: 0.9090909090909091
# /Users/Connor/Documents/GitHub/NFT-Wash-Analysis/opensea_collection.py:137: DtypeWarning: Columns (1657) have mixed types. Specify dtype option on import or set low_memory=False.
#   self.panda = pd.read_csv(directory, usecols=touseCols) # Removed low_memory=false, was running out of mem for large collections
# world of women: 0.958904109589041
# /Users/Connor/Documents/GitHub/NFT-Wash-Analysis/opensea_collection.py:137: DtypeWarning: Columns (856) have mixed types. Specify dtype option on import or set low_memory=False.
#   self.panda = pd.read_csv(directory, usecols=touseCols) # Removed low_memory=false, was running out of mem for large collections
# wvrps: 0.7857142857142857
# x_rabbits: 0.7777777777777778
# +-----------+----------------------------+
# | Graph Key |         Collection         |
# +-----------+----------------------------+
# |     1     |       0n1_force.csv        |
# |     2     |     axie_infinity.csv      |
# |     3     |         azuki.csv          |
# |     4     |       bored_ape.csv        |
# |     5     |        clone_x.csv         |
# |     6     |       coolmonkes.csv       |
# |     7     |     creature_world.csv     |
# |     8     |     creepz_reptile.csv     |
# |     9     |         creepz.csv         |
# |     10    |       cryptoadz.csv        |
# |     11    |       cryptobatz.csv       |
# |     12    |     cryptokitties.csv      |
# |     13    |      cryptopunks.csv       |
# |     14    |      cryptoskulls.csv      |
# |     15    |     cyberkongz_vx.csv      |
# |     16    |       DeadFellaz.csv       |
# |     17    | decentraland_wearables.csv |
# |     18    |       doge_pound.csv       |
# |     19    |        doodles.csv         |
# |     20    |       dr_ETHvil.csv        |
# |     21    |      emblem_vault.csv      |
# |     22    |  FLUF_world_thingies.csv   |
# |     23    |       fomo_mofos.csv       |
# |     24    |       full_send.csv        |
# |     25    |       hape_prime.csv       |
# |     26    |       hashmasks.csv        |
# |     27    |       lil_heroes.csv       |
# |     28    |       lostpoets.csv        |
# |     29    |        meebits.csv         |
# |     30    |       mekaverse.csv        |
# |     31    |       metroverse.csv       |
# |     32    |       mutant_ape.csv       |
# |     33    |     my_curio_cards.csv     |
# |     34    |       phantabear.csv       |
# |     35    |     pudgypenguins.csv      |
# |     36    |       punkcomics.csv       |
# |     37    |        rarible.csv         |
# |     38    |         rtfkt.csv          |
# |     39    |         sorare.csv         |
# |     40    |       superrare.csv        |
# |     41    |       wolf_game.csv        |
# |     42    |     world of women.csv     |
# |     43    |         wvrps.csv          |
# |     44    |       x_rabbits.csv        |
# +-----------+----------------------------+

# %% [markdown]
# ## Trade Size Roundness

# %%
plotRoundness(makeRoundnessVals())
# Out:
# C:\Users\19044\Documents\Senior Project\nft-wash-analysis\opensea_collection.py:89: DtypeWarning: Columns (128) have mixed types. Specify dtype option on import or set low_memory=False.
#   self.panda = pd.read_csv(directory, usecols=touseCols) # Removed low_memory=false, was running out of mem for large collections
# 0n1_force avg roundness calculated
# C:\Users\19044\Documents\Senior Project\nft-wash-analysis\opensea_collection.py:89: DtypeWarning: Columns (105) have mixed types. Specify dtype option on import or set low_memory=False.
#   self.panda = pd.read_csv(directory, usecols=touseCols) # Removed low_memory=false, was running out of mem for large collections
# axie_infinity avg roundness calculated
# C:\Users\19044\Documents\Senior Project\nft-wash-analysis\opensea_collection.py:89: DtypeWarning: Columns (105) have mixed types. Specify dtype option on import or set low_memory=False.
#   self.panda = pd.read_csv(directory, usecols=touseCols) # Removed low_memory=false, was running out of mem for large collections
# azuki avg roundness calculated
# C:\Users\19044\Documents\Senior Project\nft-wash-analysis\opensea_collection.py:89: DtypeWarning: Columns (128) have mixed types. Specify dtype option on import or set low_memory=False.
#   self.panda = pd.read_csv(directory, usecols=touseCols) # Removed low_memory=false, was running out of mem for large collections
# bored_ape avg roundness calculated
# clone_x avg roundness calculated
# C:\Users\19044\Documents\Senior Project\nft-wash-analysis\opensea_collection.py:89: DtypeWarning: Columns (642) have mixed types. Specify dtype option on import or set low_memory=False.
#   self.panda = pd.read_csv(directory, usecols=touseCols) # Removed low_memory=false, was running out of mem for large collections
# coolmonkes avg roundness calculated
# C:\Users\19044\Documents\Senior Project\nft-wash-analysis\opensea_collection.py:89: DtypeWarning: Columns (128) have mixed types. Specify dtype option on import or set low_memory=False.
#   self.panda = pd.read_csv(directory, usecols=touseCols) # Removed low_memory=false, was running out of mem for large collections
# creature_world avg roundness calculated
# creepz_reptile avg roundness calculated
# C:\Users\19044\Documents\Senior Project\nft-wash-analysis\opensea_collection.py:89: DtypeWarning: Columns (105) have mixed types. Specify dtype option on import or set low_memory=False.
#   self.panda = pd.read_csv(directory, usecols=touseCols) # Removed low_memory=false, was running out of mem for large collections
# creepz avg roundness calculated
# C:\Users\19044\Documents\Senior Project\nft-wash-analysis\opensea_collection.py:89: DtypeWarning: Columns (128) have mixed types. Specify dtype option on import or set low_memory=False.
#   self.panda = pd.read_csv(directory, usecols=touseCols) # Removed low_memory=false, was running out of mem for large collections
# cryptoadz avg roundness calculated
# C:\Users\19044\Documents\Senior Project\nft-wash-analysis\opensea_collection.py:89: DtypeWarning: Columns (105) have mixed types. Specify dtype option on import or set low_memory=False.
#   self.panda = pd.read_csv(directory, usecols=touseCols) # Removed low_memory=false, was running out of mem for large collections
# cryptobatz avg roundness calculated
# C:\Users\19044\Documents\Senior Project\nft-wash-analysis\opensea_collection.py:89: DtypeWarning: Columns (105) have mixed types. Specify dtype option on import or set low_memory=False.
#   self.panda = pd.read_csv(directory, usecols=touseCols) # Removed low_memory=false, was running out of mem for large collections
# cryptokitties avg roundness calculated
# C:\Users\19044\Documents\Senior Project\nft-wash-analysis\opensea_collection.py:89: DtypeWarning: Columns (105) have mixed types. Specify dtype option on import or set low_memory=False.
#   self.panda = pd.read_csv(directory, usecols=touseCols) # Removed low_memory=false, was running out of mem for large collections
# cryptopunks avg roundness calculated
# C:\Users\19044\Documents\Senior Project\nft-wash-analysis\opensea_collection.py:89: DtypeWarning: Columns (128) have mixed types. Specify dtype option on import or set low_memory=False.
#   self.panda = pd.read_csv(directory, usecols=touseCols) # Removed low_memory=false, was running out of mem for large collections
# cryptoskulls avg roundness calculated
# C:\Users\19044\Documents\Senior Project\nft-wash-analysis\opensea_collection.py:89: DtypeWarning: Columns (128) have mixed types. Specify dtype option on import or set low_memory=False.
#   self.panda = pd.read_csv(directory, usecols=touseCols) # Removed low_memory=false, was running out of mem for large collections
# cyberkongz_vx avg roundness calculated
# C:\Users\19044\Documents\Senior Project\nft-wash-analysis\opensea_collection.py:89: DtypeWarning: Columns (130) have mixed types. Specify dtype option on import or set low_memory=False.
#   self.panda = pd.read_csv(directory, usecols=touseCols) # Removed low_memory=false, was running out of mem for large collections
# DeadFellaz avg roundness calculated
# C:\Users\19044\Documents\Senior Project\nft-wash-analysis\opensea_collection.py:89: DtypeWarning: Columns (105) have mixed types. Specify dtype option on import or set low_memory=False.
#   self.panda = pd.read_csv(directory, usecols=touseCols) # Removed low_memory=false, was running out of mem for large collections
# decentraland_wearables avg roundness calculated
# C:\Users\19044\Documents\Senior Project\nft-wash-analysis\opensea_collection.py:89: DtypeWarning: Columns (128) have mixed types. Specify dtype option on import or set low_memory=False.
#   self.panda = pd.read_csv(directory, usecols=touseCols) # Removed low_memory=false, was running out of mem for large collections
# doge_pound avg roundness calculated
# C:\Users\19044\Documents\Senior Project\nft-wash-analysis\opensea_collection.py:89: DtypeWarning: Columns (927) have mixed types. Specify dtype option on import or set low_memory=False.
#   self.panda = pd.read_csv(directory, usecols=touseCols) # Removed low_memory=false, was running out of mem for large collections
# doodles avg roundness calculated
# dr_ETHvil avg roundness calculated
# C:\Users\19044\Documents\Senior Project\nft-wash-analysis\opensea_collection.py:89: DtypeWarning: Columns (128) have mixed types. Specify dtype option on import or set low_memory=False.
#   self.panda = pd.read_csv(directory, usecols=touseCols) # Removed low_memory=false, was running out of mem for large collections
# emblem_vault avg roundness calculated
# FLUF_world_thingies avg roundness calculated
# C:\Users\19044\Documents\Senior Project\nft-wash-analysis\opensea_collection.py:89: DtypeWarning: Columns (128) have mixed types. Specify dtype option on import or set low_memory=False.
#   self.panda = pd.read_csv(directory, usecols=touseCols) # Removed low_memory=false, was running out of mem for large collections
# fomo_mofos avg roundness calculated
# C:\Users\19044\Documents\Senior Project\nft-wash-analysis\opensea_collection.py:89: DtypeWarning: Columns (105) have mixed types. Specify dtype option on import or set low_memory=False.
#   self.panda = pd.read_csv(directory, usecols=touseCols) # Removed low_memory=false, was running out of mem for large collections
# full_send avg roundness calculated
# hape_prime avg roundness calculated
# C:\Users\19044\Documents\Senior Project\nft-wash-analysis\opensea_collection.py:89: DtypeWarning: Columns (128) have mixed types. Specify dtype option on import or set low_memory=False.
#   self.panda = pd.read_csv(directory, usecols=touseCols) # Removed low_memory=false, was running out of mem for large collections
# hashmasks avg roundness calculated
# lil_heroes avg roundness calculated
# C:\Users\19044\Documents\Senior Project\nft-wash-analysis\opensea_collection.py:89: DtypeWarning: Columns (128) have mixed types. Specify dtype option on import or set low_memory=False.
#   self.panda = pd.read_csv(directory, usecols=touseCols) # Removed low_memory=false, was running out of mem for large collections
# lostpoets avg roundness calculated
# C:\Users\19044\Documents\Senior Project\nft-wash-analysis\opensea_collection.py:89: DtypeWarning: Columns (105) have mixed types. Specify dtype option on import or set low_memory=False.
#   self.panda = pd.read_csv(directory, usecols=touseCols) # Removed low_memory=false, was running out of mem for large collections
# meebits avg roundness calculated
# C:\Users\19044\Documents\Senior Project\nft-wash-analysis\opensea_collection.py:89: DtypeWarning: Columns (128) have mixed types. Specify dtype option on import or set low_memory=False.
#   self.panda = pd.read_csv(directory, usecols=touseCols) # Removed low_memory=false, was running out of mem for large collections
# mekaverse avg roundness calculated
# C:\Users\19044\Documents\Senior Project\nft-wash-analysis\opensea_collection.py:89: DtypeWarning: Columns (105) have mixed types. Specify dtype option on import or set low_memory=False.
#   self.panda = pd.read_csv(directory, usecols=touseCols) # Removed low_memory=false, was running out of mem for large collections
# metroverse avg roundness calculated
# C:\Users\19044\Documents\Senior Project\nft-wash-analysis\opensea_collection.py:89: DtypeWarning: Columns (128) have mixed types. Specify dtype option on import or set low_memory=False.
#   self.panda = pd.read_csv(directory, usecols=touseCols) # Removed low_memory=false, was running out of mem for large collections
# mutant_ape avg roundness calculated
# C:\Users\19044\Documents\Senior Project\nft-wash-analysis\opensea_collection.py:89: DtypeWarning: Columns (128) have mixed types. Specify dtype option on import or set low_memory=False.
#   self.panda = pd.read_csv(directory, usecols=touseCols) # Removed low_memory=false, was running out of mem for large collections
# my_curio_cards avg roundness calculated
# C:\Users\19044\Documents\Senior Project\nft-wash-analysis\opensea_collection.py:89: DtypeWarning: Columns (105) have mixed types. Specify dtype option on import or set low_memory=False.
#   self.panda = pd.read_csv(directory, usecols=touseCols) # Removed low_memory=false, was running out of mem for large collections
# phantabear avg roundness calculated
# C:\Users\19044\Documents\Senior Project\nft-wash-analysis\opensea_collection.py:89: DtypeWarning: Columns (128) have mixed types. Specify dtype option on import or set low_memory=False.
#   self.panda = pd.read_csv(directory, usecols=touseCols) # Removed low_memory=false, was running out of mem for large collections
# pudgypenguins avg roundness calculated
# C:\Users\19044\Documents\Senior Project\nft-wash-analysis\opensea_collection.py:89: DtypeWarning: Columns (128) have mixed types. Specify dtype option on import or set low_memory=False.
#   self.panda = pd.read_csv(directory, usecols=touseCols) # Removed low_memory=false, was running out of mem for large collections
# punkcomics avg roundness calculated
# C:\Users\19044\Documents\Senior Project\nft-wash-analysis\opensea_collection.py:89: DtypeWarning: Columns (105) have mixed types. Specify dtype option on import or set low_memory=False.
#   self.panda = pd.read_csv(directory, usecols=touseCols) # Removed low_memory=false, was running out of mem for large collections
# rarible avg roundness calculated
# rtfkt avg roundness calculated
# C:\Users\19044\Documents\Senior Project\nft-wash-analysis\opensea_collection.py:89: DtypeWarning: Columns (105) have mixed types. Specify dtype option on import or set low_memory=False.
#   self.panda = pd.read_csv(directory, usecols=touseCols) # Removed low_memory=false, was running out of mem for large collections
# sorare avg roundness calculated
# C:\Users\19044\Documents\Senior Project\nft-wash-analysis\opensea_collection.py:89: DtypeWarning: Columns (105) have mixed types. Specify dtype option on import or set low_memory=False.
#   self.panda = pd.read_csv(directory, usecols=touseCols) # Removed low_memory=false, was running out of mem for large collections
# superrare avg roundness calculated
# C:\Users\19044\Documents\Senior Project\nft-wash-analysis\opensea_collection.py:89: DtypeWarning: Columns (105) have mixed types. Specify dtype option on import or set low_memory=False.
#   self.panda = pd.read_csv(directory, usecols=touseCols) # Removed low_memory=false, was running out of mem for large collections
# wolf_game avg roundness calculated
# C:\Users\19044\Documents\Senior Project\nft-wash-analysis\opensea_collection.py:89: DtypeWarning: Columns (1657) have mixed types. Specify dtype option on import or set low_memory=False.
#   self.panda = pd.read_csv(directory, usecols=touseCols) # Removed low_memory=false, was running out of mem for large collections
# world of women avg roundness calculated
# C:\Users\19044\Documents\Senior Project\nft-wash-analysis\opensea_collection.py:89: DtypeWarning: Columns (856) have mixed types. Specify dtype option on import or set low_memory=False.
#   self.panda = pd.read_csv(directory, usecols=touseCols) # Removed low_memory=false, was running out of mem for large collections
# wvrps avg roundness calculated
# x_rabbits avg roundness calculated
# +-----------+----------------------------+
# | Graph Key |         Collection         |
# +-----------+----------------------------+
# |     1     |       0n1_force.csv        |
# |     2     |     axie_infinity.csv      |
# |     3     |         azuki.csv          |
# |     4     |       bored_ape.csv        |
# |     5     |        clone_x.csv         |
# |     6     |       coolmonkes.csv       |
# |     7     |     creature_world.csv     |
# |     8     |     creepz_reptile.csv     |
# |     9     |         creepz.csv         |
# |     10    |       cryptoadz.csv        |
# |     11    |       cryptobatz.csv       |
# |     12    |     cryptokitties.csv      |
# |     13    |      cryptopunks.csv       |
# |     14    |      cryptoskulls.csv      |
# |     15    |     cyberkongz_vx.csv      |
# |     16    |       DeadFellaz.csv       |
# |     17    | decentraland_wearables.csv |
# |     18    |       doge_pound.csv       |
# |     19    |        doodles.csv         |
# |     20    |       dr_ETHvil.csv        |
# |     21    |      emblem_vault.csv      |
# |     22    |  FLUF_world_thingies.csv   |
# |     23    |       fomo_mofos.csv       |
# |     24    |       full_send.csv        |
# |     25    |       hape_prime.csv       |
# |     26    |       hashmasks.csv        |
# |     27    |       lil_heroes.csv       |
# |     28    |       lostpoets.csv        |
# |     29    |        meebits.csv         |
# |     30    |       mekaverse.csv        |
# |     31    |       metroverse.csv       |
# |     32    |       mutant_ape.csv       |
# |     33    |     my_curio_cards.csv     |
# |     34    |       phantabear.csv       |
# |     35    |     pudgypenguins.csv      |
# |     36    |       punkcomics.csv       |
# |     37    |        rarible.csv         |
# |     38    |         rtfkt.csv          |
# |     39    |         sorare.csv         |
# |     40    |       superrare.csv        |
# |     41    |       wolf_game.csv        |
# |     42    |     world of women.csv     |
# |     43    |         wvrps.csv          |
# |     44    |       x_rabbits.csv        |
# +-----------+----------------------------+
# axie_infinity is a statistical outlier with a z-score of 3.604793334791299
# cryptokitties is a statistical outlier with a z-score of 4.73001701860724
