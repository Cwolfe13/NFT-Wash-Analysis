# %%
import opensea_collection
import importlib

# %%
collectionCSVs = [
    "0n1_force.csv",
    "axie_infinity.csv",
    "azuki.csv",
    "bored_ape.csv",
    "clone_x.csv",
    "coolmonkes.csv",
    "creature_world.csv",
    "creepz_reptile.csv",
    "creeps.csv",
    "cryptoadz.csv",
    "cryptobatz.csv",
    "cryptokitties.csv",
    "cryptopunks.csv",
    "cryptoskulls.csv",
    "cyberkongz_vx.csv",
    "DeadFellaz.csv",
    "decentraland_wearables.csv",
    "doge_pound.csv",
    "doodles.csv",
    "dr_ETHvil.csv",
    "emblem_vaul.csv",
    "FLUF_world_thingies.csv",
    "fomo_mofos.csv",
    "full_send.csv",
    "hape_prime.csv",
    "hashmasks.csv",
    "lil_heroes.csv",
    "lostpoets.csv",
    "meebits.csv",
    "mekaverse.csv",
    "metroverse.csv",
    "mutant_ape.csv",
    "my_curio_cards.csv",
    "phantabear.csv",
    "pudgypenguins.csv",
    "punkcomics.csv",
    "rarible.csv",
    "rtfkt.csv",
    "sorare.csv",
    "superrare.csv",
    "wolf_game.csv",
    "world of women.csv",
    "wvrps.csv",
    "x_rabbits.csv"
]

# %%
#If you change the opensea collection file it'll need to be
#reimported to reflect any changes.
importlib.reload(opensea_collection)
# Out:
# <module 'opensea_collection' from '/Users/Connor/Documents/GitHub/NFT-Wash-Analysis/opensea_collection.py'>

# %%
my_obj = opensea_collection.collection(collectionCSVs[5])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /Users/Connor/Documents/GitHub/NFT-Wash-Analysis/analysis.ipynb Cell 4' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/Connor/Documents/GitHub/NFT-Wash-Analysis/analysis.ipynb#ch0000002?line=0'>1</a> my_obj = opensea_collection.collection(collectionCSVs[5])
#
# File ~/Documents/GitHub/NFT-Wash-Analysis/opensea_collection.py:76, in collection.__init__(self, name)
#      <a href='file:///Users/Connor/Documents/GitHub/NFT-Wash-Analysis/opensea_collection.py?line=73'>74</a> self.panda = pd.read_csv(directory, low_memory=False)
#      <a href='file:///Users/Connor/Documents/GitHub/NFT-Wash-Analysis/opensea_collection.py?line=74'>75</a> #Now we do the work on it
# ---> <a href='file:///Users/Connor/Documents/GitHub/NFT-Wash-Analysis/opensea_collection.py?line=75'>76</a> self.panda = self.clean_panda(self.panda)
#      <a href='file:///Users/Connor/Documents/GitHub/NFT-Wash-Analysis/opensea_collection.py?line=76'>77</a> #print(f'Keys: {panda.keys()}')
#      <a href='file:///Users/Connor/Documents/GitHub/NFT-Wash-Analysis/opensea_collection.py?line=77'>78</a> self.panda['adj_price'] = self.make_adjprice(self.panda)
#
# File ~/Documents/GitHub/NFT-Wash-Analysis/opensea_collection.py:129, in collection.clean_panda(self, dataframe)
#     <a href='file:///Users/Connor/Documents/GitHub/NFT-Wash-Analysis/opensea_collection.py?line=125'>126</a>     ret = dataframe.drop(bad_indices)
#     <a href='file:///Users/Connor/Documents/GitHub/NFT-Wash-Analysis/opensea_collection.py?line=126'>127</a>     return ret
# --> <a href='file:///Users/Connor/Documents/GitHub/NFT-Wash-Analysis/opensea_collection.py?line=128'>129</a> return main(dataframe)
#
# File ~/Documents/GitHub/NFT-Wash-Analysis/opensea_collection.py:107, in collection.clean_panda.<locals>.main(dataframe)
#     <a href='file:///Users/Connor/Documents/GitHub/NFT-Wash-Analysis/opensea_collection.py?line=104'>105</a> dataframe = drop_bad_rows(dataframe)
#     <a href='file:///Users/Connor/Documents/GitHub/NFT-Wash-Analysis/opensea_collection.py?line=105'>106</a> dataframe = drop_bundle(dataframe)
# --> <a href='file:///Users/Connor/Documents/GitHub/NFT-Wash-Analysis/opensea_collection.py?line=106'>107</a> dataframe = drop_nETH(dataframe)
#     <a href='file:///Users/Connor/Documents/GitHub/NFT-Wash-Analysis/opensea_collection.py?line=107'>108</a> dataframe.reset_index(inplace=True, drop=True)
#     <a href='file:///Users/Connor/Documents/GitHub/NFT-Wash-Analysis/opensea_collection.py?line=108'>109</a> return dataframe
#
# File ~/Documents/GitHub/NFT-Wash-Analysis/opensea_collection.py:125, in collection.clean_panda.<locals>.drop_nETH(dataframe)
#     <a href='file:///Users/Connor/Documents/GitHub/NFT-Wash-Analysis/opensea_collection.py?line=121'>122</a> def drop_nETH(dataframe):
#     <a href='file:///Users/Connor/Documents/GitHub/NFT-Wash-Analysis/opensea_collection.py?line=122'>123</a>     # What happens if there are no non ETH indices?
#     <a href='file:///Users/Connor/Documents/GitHub/NFT-Wash-Analysis/opensea_collection.py?line=123'>124</a>     # Likely needs error handling
# --> <a href='file:///Users/Connor/Documents/GitHub/NFT-Wash-Analysis/opensea_collection.py?line=124'>125</a>     bad_indices = dataframe[(dataframe.payment_token_id != 1) & (dataframe.payment_token_id != 2)].index
#     <a href='file:///Users/Connor/Documents/GitHub/NFT-Wash-Analysis/opensea_collection.py?line=125'>126</a>     ret = dataframe.drop(bad_indices)
#     <a href='file:///Users/Connor/Documents/GitHub/NFT-Wash-Analysis/opensea_collection.py?line=126'>127</a>     return ret
#
# File ~/Documents/GitHub/NFT-Wash-Analysis/venv/lib/python3.9/site-packages/pandas/core/generic.py:5583, in NDFrame.__getattr__(self, name)
#    <a href='file:///Users/Connor/Documents/GitHub/NFT-Wash-Analysis/venv/lib/python3.9/site-packages/pandas/core/generic.py?line=5575'>5576</a> if (
#    <a href='file:///Users/Connor/Documents/GitHub/NFT-Wash-Analysis/venv/lib/python3.9/site-packages/pandas/core/generic.py?line=5576'>5577</a>     name not in self._internal_names_set
#    <a href='file:///Users/Connor/Documents/GitHub/NFT-Wash-Analysis/venv/lib/python3.9/site-packages/pandas/core/generic.py?line=5577'>5578</a>     and name not in self._metadata
#    <a href='file:///Users/Connor/Documents/GitHub/NFT-Wash-Analysis/venv/lib/python3.9/site-packages/pandas/core/generic.py?line=5578'>5579</a>     and name not in self._accessors
#    <a href='file:///Users/Connor/Documents/GitHub/NFT-Wash-Analysis/venv/lib/python3.9/site-packages/pandas/core/generic.py?line=5579'>5580</a>     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    <a href='file:///Users/Connor/Documents/GitHub/NFT-Wash-Analysis/venv/lib/python3.9/site-packages/pandas/core/generic.py?line=5580'>5581</a> ):
#    <a href='file:///Users/Connor/Documents/GitHub/NFT-Wash-Analysis/venv/lib/python3.9/site-packages/pandas/core/generic.py?line=5581'>5582</a>     return self[name]
# -> <a href='file:///Users/Connor/Documents/GitHub/NFT-Wash-Analysis/venv/lib/python3.9/site-packages/pandas/core/generic.py?line=5582'>5583</a> return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'payment_token_id'

# %%
my_obj.plot_usd_fsd()

# %%
import matplotlib.pyplot as plt

# %%
a.savefig('test.png')

# %%
my_obj.plot_eth_fsd()

# %%
my_obj.plot_cluster(13.97)
# Out:
# Patches: <BarContainer object of 100 artists>

# %%
my_obj.plot_cluster(100)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Users/Connor/Documents/GitHub/NFT-Wash-Analysis/analysis.ipynb Cell 8' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/Connor/Documents/GitHub/NFT-Wash-Analysis/analysis.ipynb#ch0000007?line=0'>1</a> my_obj.plot_cluster(100)
#
# File ~/Documents/GitHub/NFT-Wash-Analysis/opensea_collection.py:536, in collection.plot_cluster(self, prange)
#     <a href='file:///Users/Connor/Documents/GitHub/NFT-Wash-Analysis/opensea_collection.py?line=533'>534</a>     raise TypeError('Range provided must be an int or a float')
#     <a href='file:///Users/Connor/Documents/GitHub/NFT-Wash-Analysis/opensea_collection.py?line=534'>535</a> if (prange > max(self.panda.eth_hundreths)):
# --> <a href='file:///Users/Connor/Documents/GitHub/NFT-Wash-Analysis/opensea_collection.py?line=535'>536</a>     raise ValueError(f'The range provided {prange} was greater' +
#     <a href='file:///Users/Connor/Documents/GitHub/NFT-Wash-Analysis/opensea_collection.py?line=536'>537</a>                      f'than the max transaction size {max(self.panda.eth_hundreths)}')
#     <a href='file:///Users/Connor/Documents/GitHub/NFT-Wash-Analysis/opensea_collection.py?line=537'>538</a> #Make the figure
#     <a href='file:///Users/Connor/Documents/GitHub/NFT-Wash-Analysis/opensea_collection.py?line=538'>539</a> fig = plt.figure(figsize=(8,6))
#
# ValueError: The range provided 100 was greaterthan the max transaction size 13.97

# %%
my_obj.plot_cluster(30)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Users/Connor/Documents/GitHub/NFT-Wash-Analysis/analysis.ipynb Cell 9' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/Connor/Documents/GitHub/NFT-Wash-Analysis/analysis.ipynb#ch0000009?line=0'>1</a> my_obj.plot_cluster(30)
#
# File ~/Documents/GitHub/NFT-Wash-Analysis/opensea_collection.py:528, in collection.plot_cluster(self, prange)
#     <a href='file:///Users/Connor/Documents/GitHub/NFT-Wash-Analysis/opensea_collection.py?line=525'>526</a> ax1 = fig.add_subplot()
#     <a href='file:///Users/Connor/Documents/GitHub/NFT-Wash-Analysis/opensea_collection.py?line=526'>527</a> category = 'eth_'
# --> <a href='file:///Users/Connor/Documents/GitHub/NFT-Wash-Analysis/opensea_collection.py?line=527'>528</a> if prange < 10:
#     <a href='file:///Users/Connor/Documents/GitHub/NFT-Wash-Analysis/opensea_collection.py?line=528'>529</a>     category = category + 'hundreths'
#     <a href='file:///Users/Connor/Documents/GitHub/NFT-Wash-Analysis/opensea_collection.py?line=529'>530</a>     true_range = prange + 0.01
#
# ValueError: The range provided 30 was greaterthan the max transaction size 20.0
